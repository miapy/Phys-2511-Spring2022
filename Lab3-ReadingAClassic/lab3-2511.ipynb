# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

in_file = open("frank1.txt", "r")
print(type(in_file) )
in_text = []
Victor_count = 0
creature_count = 0
Agatha_count=0
Caroline_count=0
De_count=0
Elizabeth_count=0
Ernest_count=0
Felix_count=0
Henry_count=0
Justine_count=0
William_count=0



read_data=in_file.read()
split_file=read_data.split("Chapter ")
    

for l in split_file[25:]:
        #print(l.count("Victor") )
    Victor_count = Victor_count + l.count("Victor")
    creature_count = creature_count + l.count("creature")
    Agatha_count = Agatha_count + l.count("Agatha") 
    Caroline_count = Caroline_count + l.count("Caroline")
    De_count = De_count + l.count("De Lacey")
    Elizabeth_count = Elizabeth_count + l.count("Elizabeth")
    Ernest_count = Ernest_count + l.count("Ernest")
    Felix_count = Felix_count + l.count("Felix")
    Henry_count = Henry_count + l.count("Henry")
    Justine_count = Justine_count + l.count("Justine")
    William_count = William_count + l.count("William")
   
    print(l[:2])
    print("Victor Count is:", Victor_count)
    print("creature Count is:", creature_count)   
    print("Agatha Count is:", Agatha_count)    
    print("Caroline Count is:", Caroline_count)    
    print("De Lacey Count is:", De_count)   
    print("Elizabeth Count is:", Elizabeth_count)   
    print("Ernest Count is:", Ernest_count)   
    print("Felix Count is:", Felix_count)    
    print("Henry Count is:", Henry_count)   
    print("Justine Count is:", Justine_count)  
    print("William Count is:", William_count)

    

    x=["Vic","creature","Agatha","Caroline","De L.","Liz","Ernest","Felix","Henry","Justine","Will"]
    y=(Victor_count,creature_count,Agatha_count,Caroline_count,De_count,Elizabeth_count,Ernest_count,Felix_count,Henry_count,Justine_count,William_count)

    plt.figure()
    plt.bar(x,y)
    plt.show()
    
#for m in in_file:
#print(m.count("creature") )
    
    
#print(in_text)
in_file.close()
# Out:
# <class '_io.TextIOWrapper'>
# 1
#
# Victor Count is: 1
# creature Count is: 2
# Agatha Count is: 0
# Caroline Count is: 2
# De Lacey Count is: 0
# Elizabeth Count is: 4
# Ernest Count is: 0
# Felix Count is: 0
# Henry Count is: 0
# Justine Count is: 0
# William Count is: 0
# 2
#
# Victor Count is: 2
# creature Count is: 2
# Agatha Count is: 0
# Caroline Count is: 2
# De Lacey Count is: 0
# Elizabeth Count is: 6
# Ernest Count is: 0
# Felix Count is: 0
# Henry Count is: 1
# Justine Count is: 0
# William Count is: 0
# 3
#
# Victor Count is: 2
# creature Count is: 2
# Agatha Count is: 0
# Caroline Count is: 2
# De Lacey Count is: 0
# Elizabeth Count is: 13
# Ernest Count is: 0
# Felix Count is: 0
# Henry Count is: 2
# Justine Count is: 0
# William Count is: 0
# 4
#
# Victor Count is: 2
# creature Count is: 3
# Agatha Count is: 0
# Caroline Count is: 2
# De Lacey Count is: 0
# Elizabeth Count is: 13
# Ernest Count is: 0
# Felix Count is: 0
# Henry Count is: 2
# Justine Count is: 0
# ...

# %%
n_file = open("frank1.txt", "r")
print(type(in_file) )
in_text = []
victor_count = 0
for l in in_file:
    print(l.count("shall") )
    victor_count = victor_count + l.count("shall")
print("Victor Count is:", victor_count)
print(in_text)
in_file.close()
# Out:
# <class '_io.TextIOWrapper'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/7m/yrsq0mmn6rjd0v_zdq3wwl580000gn/T/ipykernel_2189/808737832.py in <module>
#       3 in_text = []
#       4 victor_count = 0
# ----> 5 for l in in_file:
#       6     print(l.count("shall") )
#       7     victor_count = victor_count + l.count("shall")
#
# ValueError: I/O operation on closed file.

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as pyp


in_file = open("frank1.txt", "r")

for line in in_file:
    read_book=in_file.read()
    half_book=read_book.split("l")
    
    for l in half_book:
    
        vic=l.count("Victor")
    
        print(l[:2])
    
        print("vic count is", vic)
        
in_file.close()
# Out:
# T
# vic count is 0
# d
# vic count is 0
# mo
# vic count is 0
# ud
# vic count is 0
# in
# vic count is 0
# oc
# vic count is 0
#
# vic count is 0
#  h
# vic count is 0
# aw
# vic count is 0
# oc
# vic count is 0
# e:
# vic count is 0
#
# vic count is 0
# st
# vic count is 0
#
# vic count is 0
# ey
# vic count is 0
# ea
# vic count is 0
# y
# vic count is 0
# is
# vic count is 0
#
# vic count is 0
# ip
# vic count is 0
# tz
# vic count is 0
#  H
# vic count is 0
#
# vic count is 0
# st
# vic count is 0
#
# vic count is 0
# ey
# vic count is 0
#
# vic count is 0
# e,
# vic count is 0
# an
# vic count is 0
#
# vic count is 0
#  r
# vic count is 0
#
# f
# vic count is 0
# fa
# vic count is 0
# re
# vic count is 0
# k
# vic count is 0
#  a
# vic count is 0
# d
# vic count is 0
# ay
# vic count is 0
#
# vic count is 0
# s
# vic count is 0
# ig
# vic count is 0
# in
# vic count is 0
#
# vic count is 0
# ed
# vic count is 0
# im
# vic count is 0
# e
# vic count is 0
# at
# vic count is 0
# ...

# %%
# Out:
# <class '_io.TextIOWrapper'>
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# Victor Count is: 0
# ...
